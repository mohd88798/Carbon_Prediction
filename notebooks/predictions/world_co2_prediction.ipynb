# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM

# %%
# Load the CO2 concentration data
df = pd.read_csv("C:/Users/mohdz/OneDrive/Desktop/co2_mm_gl.csv")
df = df[['year', 'month', 'average']]
df['date'] = pd.to_datetime(df[['year', 'month']].assign(day=1))
df = df.set_index(df.date)
df = df[['average']]
df.head()
# Out:
#             average
# date
# 1979-01-01   336.56
# 1979-02-01   337.29
# 1979-03-01   337.88
# 1979-04-01   338.32
# 1979-05-01   338.26

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
data = scaler.fit_transform(df['average'].values.reshape(-1, 1))

# %%
train_size = int(len(data) * 0.8)
train_data, test_data = data[:train_size,:], data[train_size:,:]

# %%
# Create the training and testing datasets
def create_dataset(dataset, time_steps=1):
    X, Y = [], []
    for i in range(len(dataset)-time_steps):
        a = dataset[i:(i+time_steps), 0]
        X.append(a)
        Y.append(dataset[i + time_steps, 0])
    return np.array(X), np.array(Y)

# %%
time_steps = 3 # number of months to look back
X_train, y_train = create_dataset(train_data, time_steps)
X_test, y_test = create_dataset(test_data, time_steps)

# %%
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(X_train.shape[1], 1)))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
model.fit(X_train, y_train, epochs=100, batch_size=64, verbose=1)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 3s 6ms/step - loss: 0.1482
# Epoch 2/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0940
# Epoch 3/100
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0433
# Epoch 4/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0173
# Epoch 5/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0197
# Epoch 6/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0123
# Epoch 7/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0104
# Epoch 8/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0082
# Epoch 9/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0054
# Epoch 10/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0037
# Epoch 11/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0022
# Epoch 12/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0012
# Epoch 13/100
# 7/7 [==============================] - 0s 10ms/step - loss: 7.9106e-04
# Epoch 14/100
# 7/7 [==============================] - 0s 10ms/step - loss: 6.6496e-04
# Epoch 15/100
# 7/7 [==============================] - 0s 10ms/step - loss: 6.9607e-04
# Epoch 16/100
# 7/7 [==============================] - 0s 10ms/step - loss: 6.9816e-04
# Epoch 17/100
# 7/7 [==============================] - 0s 10ms/step - loss: 6.7800e-04
# Epoch 18/100
# 7/7 [==============================] - 0s 10ms/step - loss: 6.5430e-04
# Epoch 19/100
# 7/7 [==============================] - 0s 9ms/step - loss: 6.6057e-04
# Epoch 20/100
# 7/7 [==============================] - 0s 10ms/step - loss: 6.6345e-04
# Epoch 21/100
# 7/7 [==============================] - 0s 9ms/step - loss: 6.4719e-04
# Epoch 22/100
# 7/7 [==============================] - 0s 9ms/step - loss: 6.4331e-04
# Epoch 23/100
# 7/7 [==============================] - 0s 8ms/step - loss: 6.2560e-04
# Epoch 24/100
# 7/7 [==============================] - 0s 10ms/step - loss: 6.1984e-04
# Epoch 25/100
# 7/7 [==============================] - 0s 8ms/step - loss: 6.2052e-04
# Epoch 26/100
# 7/7 [==============================] - 0s 9ms/step - loss: 6.1278e-04
# Epoch 27/100
# 7/7 [==============================] - 0s 8ms/step - loss: 6.0144e-04
# Epoch 28/100
# 7/7 [==============================] - 0s 9ms/step - loss: 6.0087e-04
# Epoch 29/100
# 7/7 [==============================] - 0s 9ms/step - loss: 5.9469e-04
# Epoch 30/100
# 7/7 [==============================] - 0s 9ms/step - loss: 5.9016e-04
# Epoch 31/100
# 7/7 [==============================] - 0s 9ms/step - loss: 5.8140e-04
# Epoch 32/100
# 7/7 [==============================] - 0s 9ms/step - loss: 5.7899e-04
# Epoch 33/100
# 7/7 [==============================] - 0s 8ms/step - loss: 5.7327e-04
# Epoch 34/100
# 7/7 [==============================] - 0s 9ms/step - loss: 5.7055e-04
# Epoch 35/100
# 7/7 [==============================] - 0s 10ms/step - loss: 5.6353e-04
# Epoch 36/100
# 7/7 [==============================] - 0s 10ms/step - loss: 5.6014e-04
# Epoch 37/100
# 7/7 [==============================] - 0s 10ms/step - loss: 5.5351e-04
# Epoch 38/100
# 7/7 [==============================] - 0s 9ms/step - loss: 5.4691e-04
# Epoch 39/100
# 7/7 [==============================] - 0s 10ms/step - loss: 5.4721e-04
# Epoch 40/100
# 7/7 [==============================] - 0s 11ms/step - loss: 5.5137e-04
# Epoch 41/100
# 7/7 [==============================] - 0s 10ms/step - loss: 5.5986e-04
# Epoch 42/100
# 7/7 [==============================] - 0s 9ms/step - loss: 5.3876e-04
# Epoch 43/100
# 7/7 [==============================] - 0s 8ms/step - loss: 5.2833e-04
# Epoch 44/100
# 7/7 [==============================] - 0s 9ms/step - loss: 5.3481e-04
# Epoch 45/100
# 7/7 [==============================] - 0s 9ms/step - loss: 5.2508e-04
# Epoch 46/100
# 7/7 [==============================] - 0s 10ms/step - loss: 5.1820e-04
# Epoch 47/100
# 7/7 [==============================] - 0s 10ms/step - loss: 5.1818e-04
# Epoch 48/100
# 7/7 [==============================] - 0s 10ms/step - loss: 5.1760e-04
# Epoch 49/100
# 7/7 [==============================] - 0s 9ms/step - loss: 5.1199e-04
# Epoch 50/100
# 7/7 [==============================] - 0s 9ms/step - loss: 5.2353e-04
# Epoch 51/100
# 7/7 [==============================] - 0s 10ms/step - loss: 5.0834e-04
# Epoch 52/100
# 7/7 [==============================] - 0s 9ms/step - loss: 5.0076e-04
# Epoch 53/100
# 7/7 [==============================] - 0s 9ms/step - loss: 4.9589e-04
# Epoch 54/100
# 7/7 [==============================] - 0s 8ms/step - loss: 5.0978e-04
# Epoch 55/100
# 7/7 [==============================] - 0s 10ms/step - loss: 5.0352e-04
# Epoch 56/100
# 7/7 [==============================] - 0s 8ms/step - loss: 4.9353e-04
# Epoch 57/100
# 7/7 [==============================] - 0s 9ms/step - loss: 4.9011e-04
# Epoch 58/100
# 7/7 [==============================] - 0s 8ms/step - loss: 4.8917e-04
# Epoch 59/100
# 7/7 [==============================] - 0s 10ms/step - loss: 4.8470e-04
# Epoch 60/100
# 7/7 [==============================] - 0s 8ms/step - loss: 4.8545e-04
# Epoch 61/100
# 7/7 [==============================] - 0s 8ms/step - loss: 4.8290e-04
# Epoch 62/100
# 7/7 [==============================] - 0s 7ms/step - loss: 4.7907e-04
# Epoch 63/100
# 7/7 [==============================] - 0s 8ms/step - loss: 4.8218e-04
# Epoch 64/100
# 7/7 [==============================] - 0s 8ms/step - loss: 4.7663e-04
# Epoch 65/100
# 7/7 [==============================] - 0s 9ms/step - loss: 4.7770e-04
# Epoch 66/100
# 7/7 [==============================] - 0s 9ms/step - loss: 4.7554e-04
# Epoch 67/100
# 7/7 [==============================] - 0s 8ms/step - loss: 4.7985e-04
# Epoch 68/100
# 7/7 [==============================] - 0s 10ms/step - loss: 4.8044e-04
# Epoch 69/100
# 7/7 [==============================] - 0s 8ms/step - loss: 4.7327e-04
# Epoch 70/100
# 7/7 [==============================] - 0s 8ms/step - loss: 4.7391e-04
# Epoch 71/100
# 7/7 [==============================] - 0s 8ms/step - loss: 4.8060e-04
# Epoch 72/100
# 7/7 [==============================] - 0s 11ms/step - loss: 4.8264e-04
# Epoch 73/100
# 7/7 [==============================] - 0s 9ms/step - loss: 4.7557e-04
# Epoch 74/100
# 7/7 [==============================] - 0s 8ms/step - loss: 4.7291e-04
# Epoch 75/100
# 7/7 [==============================] - 0s 8ms/step - loss: 4.6932e-04
# Epoch 76/100
# 7/7 [==============================] - 0s 8ms/step - loss: 4.6805e-04
# Epoch 77/100
# 7/7 [==============================] - 0s 9ms/step - loss: 4.6607e-04
# Epoch 78/100
# 7/7 [==============================] - 0s 8ms/step - loss: 4.6497e-04
# Epoch 79/100
# 7/7 [==============================] - 0s 11ms/step - loss: 4.6761e-04
# Epoch 80/100
# 7/7 [==============================] - 0s 9ms/step - loss: 4.6471e-04
# Epoch 81/100
# 7/7 [==============================] - 0s 8ms/step - loss: 4.6312e-04
# Epoch 82/100
# 7/7 [==============================] - 0s 8ms/step - loss: 4.7345e-04
# Epoch 83/100
# 7/7 [==============================] - 0s 8ms/step - loss: 4.6974e-04
# Epoch 84/100
# 7/7 [==============================] - 0s 9ms/step - loss: 4.6902e-04
# Epoch 85/100
# 7/7 [==============================] - 0s 8ms/step - loss: 4.6553e-04
# Epoch 86/100
# 7/7 [==============================] - 0s 9ms/step - loss: 4.6359e-04
# Epoch 87/100
# 7/7 [==============================] - 0s 10ms/step - loss: 4.7103e-04
# Epoch 88/100
# 7/7 [==============================] - 0s 9ms/step - loss: 4.6235e-04
# Epoch 89/100
# 7/7 [==============================] - 0s 10ms/step - loss: 4.6276e-04
# Epoch 90/100
# 7/7 [==============================] - 0s 10ms/step - loss: 4.7542e-04
# Epoch 91/100
# 7/7 [==============================] - 0s 10ms/step - loss: 4.6781e-04
# Epoch 92/100
# 7/7 [==============================] - 0s 8ms/step - loss: 4.6611e-04
# Epoch 93/100
# 7/7 [==============================] - 0s 9ms/step - loss: 4.9089e-04
# Epoch 94/100
# 7/7 [==============================] - 0s 9ms/step - loss: 4.7788e-04
# Epoch 95/100
# 7/7 [==============================] - 0s 10ms/step - loss: 4.7221e-04
# Epoch 96/100
# 7/7 [==============================] - 0s 9ms/step - loss: 4.6290e-04
# Epoch 97/100
# 7/7 [==============================] - 0s 9ms/step - loss: 4.6203e-04
# Epoch 98/100
# 7/7 [==============================] - 0s 9ms/step - loss: 4.6416e-04
# Epoch 99/100
# 7/7 [==============================] - 0s 8ms/step - loss: 4.6745e-04
# Epoch 100/100
# 7/7 [==============================] - 0s 9ms/step - loss: 4.5925e-04

# %%
loss_per_epoch = model.history.history['loss']
plt.plot(range(len(loss_per_epoch)),loss_per_epoch)

# %%
train_predictions = model.predict(X_train)
test_predictions = model.predict(X_test)
train_predictions = scaler.inverse_transform(train_predictions)
y_train = scaler.inverse_transform([y_train])
test_predictions = scaler.inverse_transform(test_predictions)
y_test = scaler.inverse_transform([y_test])
train_score = np.sqrt(np.mean(np.square(y_train - train_predictions)))
test_score = np.sqrt(np.mean(np.square(y_test - test_predictions)))
print('Train Score: %.2f RMSE' % (train_score))
print('Test Score: %.2f RMSE' % (test_score))
# Out:
# 14/14 [==============================] - 1s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
# Train Score: 24.26 RMSE
# Test Score: 8.88 RMSE

# %%
import matplotlib.pyplot as plt
plt.plot(df['average'].values, label='Actual')
plt.plot(np.concatenate([train_predictions, test_predictions]), label='Predicted')
plt.legend()
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

ax1.plot(df['average'].values)
ax1.set_title('Actual CO2 Concentration')

ax2.plot(np.concatenate([train_predictions, test_predictions]))
ax2.set_title('Predicted CO2 Concentration')

plt.show()
