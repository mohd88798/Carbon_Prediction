# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN

# %%
# Load the CO2 concentration data
df = pd.read_csv("C:/Users/mohdz/OneDrive/Desktop/co2_mm_gl.csv")
df = df[['year', 'month', 'average']]
df['date'] = pd.to_datetime(df[['year', 'month']].assign(day=1))
df = df.set_index(df.date)
df = df[['average']]
df.head()
# Out:
#             average
# date
# 1979-01-01   336.56
# 1979-02-01   337.29
# 1979-03-01   337.88
# 1979-04-01   338.32
# 1979-05-01   338.26

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
data = scaler.fit_transform(df['average'].values.reshape(-1, 1))

# %%
train_size = int(len(data) * 0.8)
train_data, test_data = data[:train_size,:], data[train_size:,:]

# %%
# Create the training and testing datasets
def create_dataset(dataset, time_steps=1):
    X, Y = [], []
    for i in range(len(dataset)-time_steps):
        a = dataset[i:(i+time_steps), 0]
        X.append(a)
        Y.append(dataset[i + time_steps, 0])
    return np.array(X), np.array(Y)

# %%
time_steps = 24 # number of months to look back
X_train, y_train = create_dataset(train_data, time_steps)
X_test, y_test = create_dataset(test_data, time_steps)

# %%
model = Sequential()
model.add(SimpleRNN(50, return_sequences=True, input_shape=(X_train.shape[1], 1)))
model.add(SimpleRNN(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
model.fit(X_train, y_train, epochs=100, batch_size=64, verbose=1)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 1s 10ms/step - loss: 0.1055
# Epoch 2/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0057
# Epoch 3/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0025
# Epoch 4/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0022
# Epoch 5/100
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0015
# Epoch 6/100
# 7/7 [==============================] - 0s 11ms/step - loss: 7.1955e-04
# Epoch 7/100
# 7/7 [==============================] - 0s 12ms/step - loss: 5.2403e-04
# Epoch 8/100
# 7/7 [==============================] - 0s 13ms/step - loss: 4.9382e-04
# Epoch 9/100
# 7/7 [==============================] - 0s 11ms/step - loss: 3.2130e-04
# Epoch 10/100
# 7/7 [==============================] - 0s 10ms/step - loss: 2.8327e-04
# Epoch 11/100
# 7/7 [==============================] - 0s 8ms/step - loss: 1.7322e-04
# Epoch 12/100
# 7/7 [==============================] - 0s 11ms/step - loss: 1.7418e-04
# Epoch 13/100
# 7/7 [==============================] - 0s 10ms/step - loss: 2.3697e-04
# Epoch 14/100
# 7/7 [==============================] - 0s 10ms/step - loss: 2.0262e-04
# Epoch 15/100
# 7/7 [==============================] - 0s 12ms/step - loss: 1.7146e-04
# Epoch 16/100
# 7/7 [==============================] - 0s 10ms/step - loss: 1.2481e-04
# Epoch 17/100
# 7/7 [==============================] - 0s 8ms/step - loss: 1.2162e-04
# Epoch 18/100
# 7/7 [==============================] - 0s 5ms/step - loss: 1.1280e-04
# Epoch 19/100
# 7/7 [==============================] - 0s 5ms/step - loss: 1.1236e-04
# Epoch 20/100
# 7/7 [==============================] - 0s 5ms/step - loss: 1.1050e-04
# Epoch 21/100
# 7/7 [==============================] - 0s 5ms/step - loss: 1.0480e-04
# Epoch 22/100
# 7/7 [==============================] - 0s 5ms/step - loss: 1.1591e-04
# Epoch 23/100
# 7/7 [==============================] - 0s 5ms/step - loss: 1.2990e-04
# Epoch 24/100
# 7/7 [==============================] - 0s 5ms/step - loss: 1.1244e-04
# Epoch 25/100
# 7/7 [==============================] - 0s 5ms/step - loss: 1.2800e-04
# Epoch 26/100
# 7/7 [==============================] - 0s 5ms/step - loss: 1.0312e-04
# Epoch 27/100
# 7/7 [==============================] - 0s 5ms/step - loss: 1.0359e-04
# Epoch 28/100
# 7/7 [==============================] - 0s 5ms/step - loss: 1.3132e-04
# Epoch 29/100
# 7/7 [==============================] - 0s 5ms/step - loss: 1.2793e-04
# Epoch 30/100
# 7/7 [==============================] - 0s 6ms/step - loss: 9.7323e-05
# Epoch 31/100
# 7/7 [==============================] - 0s 5ms/step - loss: 1.1139e-04
# Epoch 32/100
# 7/7 [==============================] - 0s 5ms/step - loss: 1.6642e-04
# Epoch 33/100
# 7/7 [==============================] - 0s 5ms/step - loss: 1.3786e-04
# Epoch 34/100
# 7/7 [==============================] - 0s 5ms/step - loss: 1.0841e-04
# Epoch 35/100
# 7/7 [==============================] - 0s 5ms/step - loss: 1.2551e-04
# Epoch 36/100
# 7/7 [==============================] - 0s 6ms/step - loss: 8.9594e-05
# Epoch 37/100
# 7/7 [==============================] - 0s 6ms/step - loss: 8.5283e-05
# Epoch 38/100
# 7/7 [==============================] - 0s 9ms/step - loss: 8.8149e-05
# Epoch 39/100
# 7/7 [==============================] - 0s 7ms/step - loss: 1.1096e-04
# Epoch 40/100
# 7/7 [==============================] - 0s 7ms/step - loss: 1.6183e-04
# Epoch 41/100
# 7/7 [==============================] - 0s 7ms/step - loss: 1.1020e-04
# Epoch 42/100
# 7/7 [==============================] - 0s 8ms/step - loss: 1.4037e-04
# Epoch 43/100
# 7/7 [==============================] - 0s 7ms/step - loss: 8.9491e-05
# Epoch 44/100
# 7/7 [==============================] - 0s 7ms/step - loss: 1.2050e-04
# Epoch 45/100
# 7/7 [==============================] - 0s 7ms/step - loss: 1.4717e-04
# Epoch 46/100
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5265e-04
# Epoch 47/100
# 7/7 [==============================] - 0s 7ms/step - loss: 1.1339e-04
# Epoch 48/100
# 7/7 [==============================] - 0s 8ms/step - loss: 6.1365e-05
# Epoch 49/100
# 7/7 [==============================] - 0s 8ms/step - loss: 9.6638e-05
# Epoch 50/100
# 7/7 [==============================] - 0s 7ms/step - loss: 7.9984e-05
# Epoch 51/100
# 7/7 [==============================] - 0s 7ms/step - loss: 7.0887e-05
# Epoch 52/100
# 7/7 [==============================] - 0s 7ms/step - loss: 1.1613e-04
# Epoch 53/100
# 7/7 [==============================] - 0s 7ms/step - loss: 1.2913e-04
# Epoch 54/100
# 7/7 [==============================] - 0s 7ms/step - loss: 9.1090e-05
# Epoch 55/100
# 7/7 [==============================] - 0s 7ms/step - loss: 7.0964e-05
# Epoch 56/100
# 7/7 [==============================] - 0s 7ms/step - loss: 9.7482e-05
# Epoch 57/100
# 7/7 [==============================] - 0s 7ms/step - loss: 1.4066e-04
# Epoch 58/100
# 7/7 [==============================] - 0s 7ms/step - loss: 7.8810e-05
# Epoch 59/100
# 7/7 [==============================] - 0s 7ms/step - loss: 5.9486e-05
# Epoch 60/100
# 7/7 [==============================] - 0s 7ms/step - loss: 4.1578e-05
# Epoch 61/100
# 7/7 [==============================] - 0s 7ms/step - loss: 3.7982e-05
# Epoch 62/100
# 7/7 [==============================] - 0s 13ms/step - loss: 4.2164e-05
# Epoch 63/100
# 7/7 [==============================] - 0s 18ms/step - loss: 4.0635e-05
# Epoch 64/100
# 7/7 [==============================] - 0s 14ms/step - loss: 3.9959e-05
# Epoch 65/100
# 7/7 [==============================] - 0s 9ms/step - loss: 3.4784e-05
# Epoch 66/100
# 7/7 [==============================] - 0s 11ms/step - loss: 3.7481e-05
# Epoch 67/100
# 7/7 [==============================] - 0s 10ms/step - loss: 6.2869e-05
# Epoch 68/100
# 7/7 [==============================] - 0s 15ms/step - loss: 5.4693e-05
# Epoch 69/100
# 7/7 [==============================] - 0s 13ms/step - loss: 6.6297e-05
# Epoch 70/100
# 7/7 [==============================] - 0s 12ms/step - loss: 4.6738e-05
# Epoch 71/100
# 7/7 [==============================] - 0s 13ms/step - loss: 4.2105e-05
# Epoch 72/100
# 7/7 [==============================] - 0s 8ms/step - loss: 3.8850e-05
# Epoch 73/100
# 7/7 [==============================] - 0s 7ms/step - loss: 3.5320e-05
# Epoch 74/100
# 7/7 [==============================] - 0s 8ms/step - loss: 2.8924e-05
# Epoch 75/100
# 7/7 [==============================] - 0s 14ms/step - loss: 3.5387e-05
# Epoch 76/100
# 7/7 [==============================] - 0s 15ms/step - loss: 2.7539e-05
# Epoch 77/100
# 7/7 [==============================] - 0s 14ms/step - loss: 4.7224e-05
# Epoch 78/100
# 7/7 [==============================] - 0s 13ms/step - loss: 3.8489e-05
# Epoch 79/100
# 7/7 [==============================] - 0s 12ms/step - loss: 7.8455e-05
# Epoch 80/100
# 7/7 [==============================] - 0s 11ms/step - loss: 4.2665e-05
# Epoch 81/100
# 7/7 [==============================] - 0s 8ms/step - loss: 3.3003e-05
# Epoch 82/100
# 7/7 [==============================] - 0s 13ms/step - loss: 2.6288e-05
# Epoch 83/100
# 7/7 [==============================] - 0s 12ms/step - loss: 6.1482e-05
# Epoch 84/100
# 7/7 [==============================] - 0s 8ms/step - loss: 5.6904e-05
# Epoch 85/100
# 7/7 [==============================] - 0s 8ms/step - loss: 4.3239e-05
# Epoch 86/100
# 7/7 [==============================] - 0s 14ms/step - loss: 5.6586e-05
# Epoch 87/100
# 7/7 [==============================] - 0s 14ms/step - loss: 2.9419e-05
# Epoch 88/100
# 7/7 [==============================] - 0s 15ms/step - loss: 3.3426e-05
# Epoch 89/100
# 7/7 [==============================] - 0s 11ms/step - loss: 2.5204e-05
# Epoch 90/100
# 7/7 [==============================] - 0s 7ms/step - loss: 2.6170e-05
# Epoch 91/100
# 7/7 [==============================] - 0s 7ms/step - loss: 3.8776e-05
# Epoch 92/100
# 7/7 [==============================] - 0s 7ms/step - loss: 8.2425e-05
# Epoch 93/100
# 7/7 [==============================] - 0s 13ms/step - loss: 5.6522e-05
# Epoch 94/100
# 7/7 [==============================] - 0s 12ms/step - loss: 6.3186e-05
# Epoch 95/100
# 7/7 [==============================] - 0s 13ms/step - loss: 7.1211e-05
# Epoch 96/100
# 7/7 [==============================] - 0s 12ms/step - loss: 2.6734e-05
# Epoch 97/100
# 7/7 [==============================] - 0s 8ms/step - loss: 2.0088e-05
# Epoch 98/100
# 7/7 [==============================] - 0s 7ms/step - loss: 2.7642e-05
# Epoch 99/100
# 7/7 [==============================] - 0s 7ms/step - loss: 2.7088e-05
# Epoch 100/100
# 7/7 [==============================] - 0s 7ms/step - loss: 3.6191e-05

# %%
loss_per_epoch = model.history.history['loss']
plt.plot(range(len(loss_per_epoch)),loss_per_epoch)

# %%
train_predictions = model.predict(X_train)
test_predictions = model.predict(X_test)
train_predictions = scaler.inverse_transform(train_predictions)
y_train = scaler.inverse_transform([y_train])
test_predictions = scaler.inverse_transform(test_predictions)
y_test = scaler.inverse_transform([y_test])
train_score = np.sqrt(np.mean(np.square(y_train - train_predictions)))
test_score = np.sqrt(np.mean(np.square(y_test - test_predictions)))
print('Train Score: %.2f RMSE' % (train_score))
print('Test Score: %.2f RMSE' % (test_score))
# Out:
# 13/13 [==============================] - 0s 3ms/step
# 3/3 [==============================] - 0s 7ms/step
# Train Score: 23.20 RMSE
# Test Score: 6.76 RMSE

# %%
print('Train Score: %.2f RMSE' % (train_score))
print('Test Score: %.2f RMSE' % (test_score))
# Out:
# Train Score: 23.20 RMSE
# Test Score: 6.76 RMSE

# %%
mse = np.mean(np.square(y_test - test_predictions))
mse
# Out:
# 45.71449426644539

# %%
import matplotlib.pyplot as plt
plt.plot(df['average'].values, label='Actual')
plt.plot(np.concatenate([train_predictions, test_predictions]), label='Predicted')
plt.legend()
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

ax1.plot(df['average'].values)
ax1.set_title('Actual CO2 Concentration')

ax2.plot(np.concatenate([train_predictions, test_predictions]))
ax2.set_title('Predicted CO2 Concentration')

plt.show()

# %%
# time_steps = 12
last_time_steps = data[-time_steps:]
future_predictions = []
for i in range(24):
    next_prediction = model.predict(last_time_steps.reshape(1, 24, 1))
    future_predictions.append(next_prediction[0,0])
    last_time_steps = np.concatenate([last_time_steps[1:], next_prediction], axis=0)
# Out:
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step

# %%
future_predictions = scaler.inverse_transform(np.array(future_predictions).reshape(-1,1))

# %%
plt.plot(df['average'].values, label='Actual')
plt.plot(np.concatenate([train_predictions, test_predictions, future_predictions]), label='Predicted')
plt.legend()
plt.show()
