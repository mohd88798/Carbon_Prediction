# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN

# %%
country = 'India'
df = pd.read_csv("../../../data/processed/co2_country.csv", index_col='year', parse_dates=True)
df = df.loc[df['country'] == country, ['co2']]
df.head()
# Out:
#                co2
# year
# 1950-01-01  61.103
# 1951-01-01  64.022
# 1952-01-01  67.426
# 1953-01-01  68.705
# 1954-01-01  72.414

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
data = scaler.fit_transform(df['co2'].values.reshape(-1, 1))

# %%
train_size = int(len(data) * 0.9)
train_data, test_data = data[:train_size,:], data[train_size:,:]

# %%
# Create the training and testing datasets
def create_dataset(dataset, time_steps=1):
    X, Y = [], []
    for i in range(len(dataset)-time_steps):
        a = dataset[i:(i+time_steps), 0]
        X.append(a)
        Y.append(dataset[i + time_steps, 0])
    return np.array(X), np.array(Y)

# %%
time_steps = 1
X_train, y_train = create_dataset(train_data, time_steps)
X_test, y_test = create_dataset(test_data, time_steps)

# %%
model = Sequential()
model.add(SimpleRNN(50, return_sequences=True, input_shape=(X_train.shape[1], 1)))
model.add(SimpleRNN(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam', run_eagerly=True)

# %%
model.fit(X_train, y_train, epochs=100, batch_size=64, verbose=1)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 0s 119ms/step - loss: 0.0406
# Epoch 2/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0289
# Epoch 3/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0195
# Epoch 4/100
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0125
# Epoch 5/100
# 1/1 [==============================] - 0s 26ms/step - loss: 0.0079
# Epoch 6/100
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0055
# Epoch 7/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0049
# Epoch 8/100
# 1/1 [==============================] - 0s 25ms/step - loss: 0.0054
# Epoch 9/100
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0063
# Epoch 10/100
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0070
# Epoch 11/100
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0073
# Epoch 12/100
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0069
# Epoch 13/100
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0061
# Epoch 14/100
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0050
# Epoch 15/100
# 1/1 [==============================] - 0s 25ms/step - loss: 0.0038
# Epoch 16/100
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0026
# Epoch 17/100
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0016
# Epoch 18/100
# 1/1 [==============================] - 0s 46ms/step - loss: 8.5652e-04
# Epoch 19/100
# 1/1 [==============================] - 0s 25ms/step - loss: 4.2971e-04
# Epoch 20/100
# 1/1 [==============================] - 0s 25ms/step - loss: 2.7492e-04
# Epoch 21/100
# 1/1 [==============================] - 0s 24ms/step - loss: 3.3199e-04
# Epoch 22/100
# 1/1 [==============================] - 0s 29ms/step - loss: 5.2015e-04
# Epoch 23/100
# 1/1 [==============================] - 0s 30ms/step - loss: 7.5494e-04
# Epoch 24/100
# 1/1 [==============================] - 0s 23ms/step - loss: 9.6325e-04
# Epoch 25/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0011
# Epoch 26/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0011
# Epoch 27/100
# 1/1 [==============================] - 0s 25ms/step - loss: 0.0011
# Epoch 28/100
# 1/1 [==============================] - 0s 37ms/step - loss: 9.0354e-04
# Epoch 29/100
# 1/1 [==============================] - 0s 32ms/step - loss: 7.1266e-04
# Epoch 30/100
# 1/1 [==============================] - 0s 31ms/step - loss: 5.1833e-04
# Epoch 31/100
# 1/1 [==============================] - 0s 25ms/step - loss: 3.5511e-04
# Epoch 32/100
# 1/1 [==============================] - 0s 26ms/step - loss: 2.4695e-04
# Epoch 33/100
# 1/1 [==============================] - 0s 24ms/step - loss: 2.0353e-04
# Epoch 34/100
# 1/1 [==============================] - 0s 24ms/step - loss: 2.1984e-04
# Epoch 35/100
# 1/1 [==============================] - 0s 29ms/step - loss: 2.7875e-04
# Epoch 36/100
# 1/1 [==============================] - 0s 23ms/step - loss: 3.5609e-04
# Epoch 37/100
# 1/1 [==============================] - 0s 24ms/step - loss: 4.2688e-04
# Epoch 38/100
# 1/1 [==============================] - 0s 26ms/step - loss: 4.7116e-04
# Epoch 39/100
# 1/1 [==============================] - 0s 30ms/step - loss: 4.7795e-04
# Epoch 40/100
# 1/1 [==============================] - 0s 27ms/step - loss: 4.4657e-04
# Epoch 41/100
# 1/1 [==============================] - 0s 25ms/step - loss: 3.8530e-04
# Epoch 42/100
# 1/1 [==============================] - 0s 31ms/step - loss: 3.0799e-04
# Epoch 43/100
# 1/1 [==============================] - 0s 23ms/step - loss: 2.3005e-04
# Epoch 44/100
# 1/1 [==============================] - 0s 26ms/step - loss: 1.6457e-04
# Epoch 45/100
# 1/1 [==============================] - 0s 48ms/step - loss: 1.1977e-04
# Epoch 46/100
# 1/1 [==============================] - 0s 35ms/step - loss: 9.7962e-05
# Epoch 47/100
# 1/1 [==============================] - 0s 26ms/step - loss: 9.6058e-05
# Epoch 48/100
# 1/1 [==============================] - 0s 26ms/step - loss: 1.0729e-04
# Epoch 49/100
# 1/1 [==============================] - 0s 31ms/step - loss: 1.2343e-04
# Epoch 50/100
# 1/1 [==============================] - 0s 27ms/step - loss: 1.3698e-04
# Epoch 51/100
# 1/1 [==============================] - 0s 23ms/step - loss: 1.4282e-04
# Epoch 52/100
# 1/1 [==============================] - 0s 25ms/step - loss: 1.3896e-04
# Epoch 53/100
# 1/1 [==============================] - 0s 29ms/step - loss: 1.2650e-04
# Epoch 54/100
# 1/1 [==============================] - 0s 29ms/step - loss: 1.0876e-04
# Epoch 55/100
# 1/1 [==============================] - 0s 28ms/step - loss: 9.0128e-05
# Epoch 56/100
# 1/1 [==============================] - 0s 22ms/step - loss: 7.4704e-05
# Epoch 57/100
# 1/1 [==============================] - 0s 25ms/step - loss: 6.5311e-05
# Epoch 58/100
# 1/1 [==============================] - 0s 29ms/step - loss: 6.2914e-05
# Epoch 59/100
# 1/1 [==============================] - 0s 28ms/step - loss: 6.6612e-05
# Epoch 60/100
# 1/1 [==============================] - 0s 21ms/step - loss: 7.4112e-05
# Epoch 61/100
# 1/1 [==============================] - 0s 23ms/step - loss: 8.2518e-05
# Epoch 62/100
# 1/1 [==============================] - 0s 21ms/step - loss: 8.9162e-05
# Epoch 63/100
# 1/1 [==============================] - 0s 23ms/step - loss: 9.2275e-05
# Epoch 64/100
# 1/1 [==============================] - 0s 23ms/step - loss: 9.1313e-05
# Epoch 65/100
# 1/1 [==============================] - 0s 27ms/step - loss: 8.6906e-05
# Epoch 66/100
# 1/1 [==============================] - 0s 24ms/step - loss: 8.0495e-05
# Epoch 67/100
# 1/1 [==============================] - 0s 21ms/step - loss: 7.3806e-05
# Epoch 68/100
# 1/1 [==============================] - 0s 27ms/step - loss: 6.8328e-05
# Epoch 69/100
# 1/1 [==============================] - 0s 22ms/step - loss: 6.4947e-05
# Epoch 70/100
# 1/1 [==============================] - 0s 25ms/step - loss: 6.3807e-05
# Epoch 71/100
# 1/1 [==============================] - 0s 46ms/step - loss: 6.4407e-05
# Epoch 72/100
# 1/1 [==============================] - 0s 31ms/step - loss: 6.5856e-05
# Epoch 73/100
# 1/1 [==============================] - 0s 27ms/step - loss: 6.7206e-05
# Epoch 74/100
# 1/1 [==============================] - 0s 29ms/step - loss: 6.7736e-05
# Epoch 75/100
# 1/1 [==============================] - 0s 28ms/step - loss: 6.7129e-05
# Epoch 76/100
# 1/1 [==============================] - 0s 35ms/step - loss: 6.5498e-05
# Epoch 77/100
# 1/1 [==============================] - 0s 31ms/step - loss: 6.3282e-05
# Epoch 78/100
# 1/1 [==============================] - 0s 28ms/step - loss: 6.1063e-05
# Epoch 79/100
# 1/1 [==============================] - 0s 28ms/step - loss: 5.9363e-05
# Epoch 80/100
# 1/1 [==============================] - 0s 32ms/step - loss: 5.8494e-05
# Epoch 81/100
# 1/1 [==============================] - 0s 24ms/step - loss: 5.8492e-05
# Epoch 82/100
# 1/1 [==============================] - 0s 30ms/step - loss: 5.9144e-05
# Epoch 83/100
# 1/1 [==============================] - 0s 24ms/step - loss: 6.0091e-05
# Epoch 84/100
# 1/1 [==============================] - 0s 27ms/step - loss: 6.0954e-05
# Epoch 85/100
# 1/1 [==============================] - 0s 25ms/step - loss: 6.1452e-05
# Epoch 86/100
# 1/1 [==============================] - 0s 25ms/step - loss: 6.1473e-05
# Epoch 87/100
# 1/1 [==============================] - 0s 31ms/step - loss: 6.1073e-05
# Epoch 88/100
# 1/1 [==============================] - 0s 25ms/step - loss: 6.0433e-05
# Epoch 89/100
# 1/1 [==============================] - 0s 29ms/step - loss: 5.9773e-05
# Epoch 90/100
# 1/1 [==============================] - 0s 30ms/step - loss: 5.9280e-05
# Epoch 91/100
# 1/1 [==============================] - 0s 25ms/step - loss: 5.9046e-05
# Epoch 92/100
# 1/1 [==============================] - 0s 25ms/step - loss: 5.9063e-05
# Epoch 93/100
# 1/1 [==============================] - 0s 26ms/step - loss: 5.9238e-05
# Epoch 94/100
# 1/1 [==============================] - 0s 32ms/step - loss: 5.9441e-05
# Epoch 95/100
# 1/1 [==============================] - 0s 27ms/step - loss: 5.9555e-05
# Epoch 96/100
# 1/1 [==============================] - 0s 55ms/step - loss: 5.9518e-05
# Epoch 97/100
# 1/1 [==============================] - 0s 29ms/step - loss: 5.9329e-05
# Epoch 98/100
# 1/1 [==============================] - 0s 30ms/step - loss: 5.9042e-05
# Epoch 99/100
# 1/1 [==============================] - 0s 28ms/step - loss: 5.8741e-05
# Epoch 100/100
# 1/1 [==============================] - 0s 28ms/step - loss: 5.8503e-05

# %%
train_predictions = model.predict(X_train)
test_predictions = model.predict(X_test)
train_predictions = scaler.inverse_transform(train_predictions)
y_train = scaler.inverse_transform([y_train])
test_predictions = scaler.inverse_transform(test_predictions)
y_test = scaler.inverse_transform([y_test])
# Out:
# 2/2 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 27ms/step

# %%
train_score = np.sqrt(np.mean(np.square(y_train - train_predictions)))
test_score = np.sqrt(np.mean(np.square(y_test - test_predictions)))
print('Train Score: %.2f RMSE' % (train_score))
print('Test Score: %.2f RMSE' % (test_score))
# Out:
# Train Score: 738.50 RMSE
# Test Score: 199.61 RMSE

# %%
import matplotlib.pyplot as plt
plt.plot(df['co2'].values[:-1], label='Actual')
plt.plot(np.concatenate([train_predictions, test_predictions]), label='Predicted')
plt.legend()
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

ax1.plot(df['co2'].values)
ax1.set_title('Actual CO2 Concentration')

ax2.plot(np.concatenate([train_predictions, test_predictions]))
ax2.set_title('Predicted CO2 Concentration')

plt.show()

# %%
last_time_steps = data[-time_steps:]
future_predictions = []
for i in range(20): 
    next_prediction = model.predict(last_time_steps.reshape(1, time_steps, 1))
    future_predictions.append(next_prediction[0,0])
    last_time_steps = np.concatenate([last_time_steps[1:], next_prediction], axis=0)
# Out:
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step

# %%
future_predictions = scaler.inverse_transform(np.array(future_predictions).reshape(-1,1))

# %%
plt.plot(df['co2'].values, label='Actual')
plt.plot(np.concatenate([train_predictions, test_predictions, future_predictions]), label='Future Prediction')
plt.legend()
plt.show()
