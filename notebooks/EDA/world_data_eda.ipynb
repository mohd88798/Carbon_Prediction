# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly_express as px

# %%
df = pd.read_csv('C:/Users/mohdz/OneDrive/Desktop/Mini_Project/data/processed/co2_world.csv')
df.head()
# Out:
#          date     co2
# 0  1979-01-01  336.56
# 1  1979-02-01  337.29
# 2  1979-03-01  337.88
# 3  1979-04-01  338.32
# 4  1979-05-01  338.26

# %%
df.columns
# Out:
# Index(['date', 'co2'], dtype='object')

# %%
df.count()
# Out:
# date    528
# co2     528
# dtype: int64

# %%
df['year'] = pd.DatetimeIndex(df['date']).year
plt.plot(df['year'],df['co2'])

plt.xlabel('Year')
plt.ylabel('CO2 Emissions')
plt.title('World CO2 Emissions from 1779 to 2021')

plt.show()
